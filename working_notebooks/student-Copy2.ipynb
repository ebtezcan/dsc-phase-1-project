# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Berke Tezcan
# * Student pace: full time
# * Scheduled project review date/time:
# * Instructor name: James Irving
# * Blog post URL:

# %% [markdown]
# ## Importing Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os

# %%
folder ='zippedData/'
os.listdir(folder)
# Out:
# ['bom.movie_gross.csv.gz',
#  'imdb.name.basics.csv.gz',
#  'imdb.title.akas.csv.gz',
#  'imdb.title.basics.csv.gz',
#  'imdb.title.crew.csv.gz',
#  'imdb.title.principals.csv.gz',
#  'imdb.title.ratings.csv.gz',
#  'rt.movie_info.tsv.gz',
#  'rt.reviews.tsv.gz',
#  'tmdb.movies.csv.gz',
#  'tn.movie_budgets.csv.gz']

# %%
bom_movie_gross = pd.read_csv(f'{folder}bom.movie_gross.csv.gz')
imdb_name_basics = pd.read_csv(f'{folder}imdb.name.basics.csv.gz')
imdb_title_akas = pd.read_csv(f'{folder}imdb.title.akas.csv.gz')
imdb_title_basics = pd.read_csv(f'{folder}imdb.title.basics.csv.gz')
imdb_title_crew = pd.read_csv(f'{folder}imdb.title.crew.csv.gz')
imdb_title_principals = pd.read_csv(f'{folder}imdb.title.principals.csv.gz')
imdb_title_ratings = pd.read_csv(f'{folder}imdb.title.ratings.csv.gz')
rt_movie_info = pd.read_csv(f'{folder}rt.movie_info.tsv.gz', delimiter='\t')
rt_reviews = pd.read_csv(f'{folder}rt.reviews.tsv.gz', delimiter='\t', encoding='latin1')
tmdb_movies = pd.read_csv(f'{folder}tmdb.movies.csv.gz',index_col=0)
tn_movie_budgets = pd.read_csv(f'{folder}tn.movie_budgets.csv.gz')

# %%
tmdb_movies.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
tmdb_movies['id'].value_counts()
# Out:
# 292086    3
# 463839    3
# 11976     3
# 391872    3
# 416572    3
#          ..
# 356987    1
# 350846    1
# 479871    1
# 500353    1
# 524288    1
# Name: id, Length: 25497, dtype: int64

# %%
tn_movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
bom_movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
imdb_name_basics.head()
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %%
imdb_title_akas.head()
# Out:
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0

# %%
imdb_title_principals.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
imdb_title_crew.head()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
imdb_title_ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
rt_movie_info.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
rt_reviews.head()
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %%
tmdb_movies.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
imdb_title_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %% [markdown]
# # Release Date vs. Profit

# %% [markdown]
# ### EDA to determine which movie df to use (looking at Sample Size, n)

# %%
#EDA to figure out which dataframe has most movies for the past decade 2010 on excluding 2020.

movies_financials = pd.merge(imdb_title_basics, bom_movie_gross, how="left", left_on='primary_title', right_on='title')
movies_financials.isna().sum()
# len(tmdb_movies) #26517
# len(bom_movie_gross) #3387
# len(imdb_title_basics) #146144
# Out:
# tconst                  0
# primary_title           0
# original_title         21
# start_year              0
# runtime_minutes     31739
# genres               5408
# title              142780
# studio             142783
# domestic_gross     142804
# foreign_gross      144103
# year               142780
# dtype: int64

# %%
imdb_title_basics[(imdb_title_basics['start_year']>=2010) & (imdb_title_basics['start_year']!=2020)] #937 rows in 2020
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                   NaN
# 146143              NaN           Documentary
#
# [145207 rows x 6 columns]

# %%
imdb_title_basics['start_year'].min()
# Out:
# 2010

# %%
imdb_title_basics['start_year'].unique()
# Out:
# array([2013, 2019, 2018, 2017, 2012, 2010, 2011, 2015, 2021, 2016, 2014,
#        2020, 2022, 2023, 2024, 2026, 2025, 2115, 2027], dtype=int64)

# %%
tmdb_movies['release_year'] = tmdb_movies['release_date'].map(lambda x: x[:4])
tmdb_movies['release_year'].dtype
# Out:
# dtype('O')

# %%
tmdb_movies['release_year'] = tmdb_movies['release_year'].astype('int64')

# %%
df = tmdb_movies[(tmdb_movies['release_year']>2010) & (tmdb_movies['release_year']!=2020)]

# %%
df['release_year'].unique()
# Out:
# array([2012, 2011, 2014, 2013, 2015, 2017, 2016, 2018, 2019], dtype=int64)

# %%
len(df) #23,884
# Out:
# 23884

# %%
df.head()
# Out:
#                genre_ids     id original_language             original_title  \
# 258             [18, 35]  39356                en                        Boy
# 289             [35, 18]  46829                en           Barney's Version
# 386                 [18]  54602                en                  Skateland
# 409         [28, 18, 53]  56812                es  Balada triste de trompeta
# 470  [53, 18, 10749, 80]  47261                es                   Carancho
#
#      popularity release_date             title  vote_average  vote_count  \
# 258       7.759   2012-03-02               Boy           7.5         149
# 289       7.357   2011-01-14  Barney's Version           7.2         210
# 386       5.938   2011-05-13         Skateland           5.4          16
# 409       5.552   2011-08-19   The Last Circus           6.7         177
# 470       4.554   2011-02-11          Carancho           6.6          59
#
#      release_year
# 258          2012
# 289          2011
# 386          2011
# 409          2011
# 470          2011

# %% [markdown]
# ### Checking for duplicates

# %%
df[df.duplicated()]
# Out:
#                  genre_ids      id original_language  \
# 2803              [35, 18]   46829                en
# 2919                  [18]   54602                en
# 2946          [28, 18, 53]   56812                es
# 3030   [53, 18, 10749, 80]   47261                es
# 3184       [10749, 35, 18]   70588                en
# ...                    ...     ...               ...
# 26481             [35, 18]  270805                en
# 26485             [27, 53]  453259                en
# 26504         [27, 35, 27]  534282                en
# 26510                 [99]  495045                en
# 26511                 [99]  492837                en
#
#                            original_title  popularity release_date  \
# 2803                     Barney's Version       7.357   2011-01-14
# 2919                            Skateland       5.938   2011-05-13
# 2946            Balada triste de trompeta       5.552   2011-08-19
# 3030                             Carancho       4.554   2011-02-11
# 3184   The Myth of the American Sleepover       3.066   2011-07-22
# ...                                   ...         ...          ...
# 26481                       Summer League       0.600   2013-03-18
# 26485              Devils in the Darkness       0.600   2013-05-15
# 26504                                Head       0.600   2015-03-28
# 26510                          Fail State       0.600   2018-10-19
# 26511                   Making Filmmakers       0.600   2018-04-07
#
#                                     title  vote_average  vote_count  \
# 2803                     Barney's Version           7.2         210
# 2919                            Skateland           5.4          16
# 2946                      The Last Circus           6.7         177
# 3030                             Carancho           6.6          59
# 3184   The Myth of the American Sleepover           6.2          47
# ...                                   ...           ...         ...
# 26481                       Summer League           4.0           3
# 26485              Devils in the Darkness           3.5           1
# 26504                                Head           1.0           1
# 26510                          Fail State           0.0           1
# 26511                   Making Filmmakers           0.0           1
#
#        release_year
# 2803           2011
# 2919           2011
# 2946           2011
# 3030           2011
# 3184           2011
# ...             ...
# 26481          2013
# 26485          2013
# 26504          2015
# 26510          2018
# 26511          2018
#
# [990 rows x 10 columns]

# %% [markdown]
# It looks like there is 990 rows that are duplicated. I will check a couple id numbers to make sure that the duplicated method is running correctly.

# %%
df[df['id']==46829]
# Out:
#      genre_ids     id original_language    original_title  popularity  \
# 289   [35, 18]  46829                en  Barney's Version       7.357
# 2803  [35, 18]  46829                en  Barney's Version       7.357
#
#      release_date             title  vote_average  vote_count  release_year
# 289    2011-01-14  Barney's Version           7.2         210          2011
# 2803   2011-01-14  Barney's Version           7.2         210          2011

# %%
df[df['id']==54602]
# Out:
#      genre_ids     id original_language original_title  popularity  \
# 386       [18]  54602                en      Skateland       5.938
# 2919      [18]  54602                en      Skateland       5.938
#
#      release_date      title  vote_average  vote_count  release_year
# 386    2011-05-13  Skateland           5.4          16          2011
# 2919   2011-05-13  Skateland           5.4          16          2011

# %% [markdown]
# ### Dropping duplicates

# %%
df = df.drop_duplicates(keep='first')

# %%
df[df['id']==46829]
# Out:
#     genre_ids     id original_language    original_title  popularity  \
# 289  [35, 18]  46829                en  Barney's Version       7.357
#
#     release_date             title  vote_average  vote_count  release_year
# 289   2011-01-14  Barney's Version           7.2         210          2011

# %% [markdown]
# ### Checking for missing/placeholder values

# %%
df.isna().sum()
# Out:
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# release_year         0
# dtype: int64

# %%
df[df['title']==None]
# Out:
# Empty DataFrame
# Columns: [genre_ids, id, original_language, original_title, popularity, release_date, title, vote_average, vote_count, release_year]
# Index: []

# %% [markdown]
# ### EDA to figure out which financial df to use, looking at sample size

# %%
len(tn_movie_budgets) #5782
# len(bom_movie_gross) #3387
# Out:
# 5782

# %%
release_profit = pd.merge(df, bom_movie_gross, how='inner', left_on='title', right_on='title')
len(release_profit)
# Out:
# 2189

# %%
release_profit = pd.merge(df, tn_movie_budgets, how='inner', left_on='title', right_on='movie')
len(release_profit)
# Out:
# 1903

# %%
tn_movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
# tn_movie_budgets[tn_movie_budgets['movie'].map(lambda x: x.startswith('Harry Potter'))]

# %%
tn_movie_budgets['worldwide_gross'] = tn_movie_budgets['worldwide_gross'].map(lambda x: x[1:].replace(',',''))

# %%
tn_movie_budgets['worldwide_gross'] = tn_movie_budgets['worldwide_gross'].astype('int64')

# %%
tn_movie_budgets['worldwide_gross'].dtype
# Out:
# dtype('int64')

# %%
def convertdollarstoint(df, col):
    df[col] = df[col].map(lambda x: x[1:].replace(',',''))
    df[col] = df[col].astype('int64')
    return df

# %%
convertdollarstoint(df = tn_movie_budgets, col = 'domestic_gross')
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget  domestic_gross  worldwide_gross
# 0         $425,000,000       760507625       2776345279
# 1         $410,600,000       241063875       1045663875
# 2         $350,000,000        42762350        149762350
# 3         $330,600,000       459005868       1403013963
# 4         $317,000,000       620181382       1316721747
# ...                ...             ...              ...
# 5777            $7,000               0                0
# 5778            $6,000           48482           240495
# 5779            $5,000            1338             1338
# 5780            $1,400               0                0
# 5781            $1,100          181041           181041
#
# [5782 rows x 6 columns]

# %%
convertdollarstoint(df = tn_movie_budgets, col = 'production_budget')
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross
# 0             425000000       760507625       2776345279
# 1             410600000       241063875       1045663875
# 2             350000000        42762350        149762350
# 3             330600000       459005868       1403013963
# 4             317000000       620181382       1316721747
# ...                 ...             ...              ...
# 5777               7000               0                0
# 5778               6000           48482           240495
# 5779               5000            1338             1338
# 5780               1400               0                0
# 5781               1100          181041           181041
#
# [5782 rows x 6 columns]

# %%
tn_movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747

# %%
tn_movie_budgets['profit'] = tn_movie_budgets['worldwide_gross'] - tn_movie_budgets['production_budget']
tn_movie_budgets['profit %'] = (((tn_movie_budgets['worldwide_gross'] - tn_movie_budgets['production_budget'])/tn_movie_budgets['production_budget'])*100).round(0)
tn_movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross      profit  profit %
# 0          425000000       760507625       2776345279  2351345279     553.0
# 1          410600000       241063875       1045663875   635063875     155.0
# 2          350000000        42762350        149762350  -200237650     -57.0
# 3          330600000       459005868       1403013963  1072413963     324.0
# 4          317000000       620181382       1316721747   999721747     315.0

# %%
tn_movie_budgets['release_month'] = tn_movie_budgets['release_date'].map(lambda x: x[:3])

# %%
tn_movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross      profit  profit %  \
# 0          425000000       760507625       2776345279  2351345279     553.0
# 1          410600000       241063875       1045663875   635063875     155.0
# 2          350000000        42762350        149762350  -200237650     -57.0
# 3          330600000       459005868       1403013963  1072413963     324.0
# 4          317000000       620181382       1316721747   999721747     315.0
#
#   release_month
# 0           Dec
# 1           May
# 2           Jun
# 3           May
# 4           Dec

# %% [markdown]
# ### Visualizations

# %%
fig, ax = plt.subplots()
plt.scatter(x=tn_movie_budgets['release_month'], y=tn_movie_budgets['profit %'])
plt.ylim(top=60000)
# Out:
# (-9100.0, 60000.0)

# %%
conversion = {'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6, 'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12}
tn_movie_budgets['release_mo_num'] = tn_movie_budgets['release_month'].map(conversion)

# %% [markdown]
# #### Profit (%) vs. Release month

# %%
plt.scatter(x=tn_movie_budgets['release_mo_num'], y=tn_movie_budgets['profit %'])
plt.ylim((-10000,60000))
# Out:
# (-10000.0, 60000.0)

# %% [markdown]
# #### Profit ($) vs. Release month

# %%
plt.scatter(x=tn_movie_budgets['release_mo_num'], y=tn_movie_budgets['profit'])

# %% [markdown]
# #### Worldwide Revenue vs. Release month

# %%
order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
medians = tn_movie_budgets.groupby('release_month')['worldwide_gross'].median().reset_index()
medians
# Out:
#    release_month  worldwide_gross
# 0            Apr       20068010.0
# 1            Aug       24202936.5
# 2            Dec       31166312.0
# 3            Feb       33097834.5
# 4            Jan       20169934.0
# 5            Jul       51134699.5
# 6            Jun       46844357.0
# 7            Mar       25599836.0
# 8            May       29934477.0
# 9            Nov       50530475.5
# 10           Oct       16628751.0
# 11           Sep       18535575.0

# %%
sns.lineplot(x=medians['release_month'], y=medians['worldwide_gross'])#x=tn_movie_budgets['release_month'], y=medians)
# Out:
# <AxesSubplot:xlabel='release_month', ylabel='worldwide_gross'>

# %%
sns.catplot(data = tn_movie_budgets, x='release_month', y='worldwide_gross', order=order, kind='swarm')
# Out:
# C:\Users\berke\anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 91.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\berke\anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 89.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\berke\anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 90.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\berke\anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 92.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\berke\anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 81.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\berke\anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 85.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\berke\anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 83.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\berke\anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 92.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\berke\anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 93.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\berke\anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 94.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\berke\anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 86.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\berke\anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 91.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.scatter(x=tn_movie_budgets['release_mo_num'], y=tn_movie_budgets['worldwide_gross'])

# %% [markdown]
# #### Domestic Revenue vs. Release month

# %%
plt.scatter(x=tn_movie_budgets['release_mo_num'], y=tn_movie_budgets['domestic_gross'])

# %%
sns.boxplot(x=tn_movie_budgets['release_mo_num'], y=tn_movie_budgets['worldwide_gross'], showfliers=False) #without outliers
# Out:
# <AxesSubplot:xlabel='release_mo_num', ylabel='worldwide_gross'>

# %%
tn_movie_budgets['profit'].max()
# Out:
# 2351345279

# %%
tn_movie_budgets[tn_movie_budgets['profit']==2351345279]
# Out:
#    id  release_date   movie  production_budget  domestic_gross  \
# 0   1  Dec 18, 2009  Avatar          425000000       760507625
#
#    worldwide_gross      profit  profit % release_month  release_mo_num
# 0       2776345279  2351345279     553.0           Dec              12

# %%
tn_movie_budgets['release_year'] = tn_movie_budgets['release_date'].map(lambda x: x[-5:])

# %%
tn_movie_budgets['release_year'] = tn_movie_budgets['release_year'].astype('int64')

# %% [markdown]
# ### Exploring ratings for movies prior to merge to see what the median and mean values of ratings are

# %%
plt.hist(x=tmdb_movies['vote_average'], bins='auto')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
tmdb_movies[tmdb_movies['vote_count']==0]
# Out:
# Empty DataFrame
# Columns: [genre_ids, id, original_language, original_title, popularity, release_date, title, vote_average, vote_count, release_year]
# Index: []

# %% [markdown]
# All movies seem to have votes on their ratings which means we can use the vote_average information without having to fill any NaN values.

# %%
tmdb_movies['vote_average'].agg('mean')
# Out:
# 5.991281064977184

# %%
tt = tmdb_movies[tmdb_movies['release_year']>=2009]
tt['vote_average'].agg('mean')
# Out:
# 5.986039269302343

# %%
tt['vote_average'].agg('mode')
# Out:
# 0    6.0
# dtype: float64

# %% [markdown]
# ### Defining a "successful movie" - larger than x% profit and higher than x rating & Filtering by successful movies.

# %% [markdown]
# It seems like the mean, median and mode values for the movie ratings converge to a 6.0 rating. Since Microsoft is just opening up this studio they will want to not only turn a profit but make movies that the public likes. A movie can turn a profit but not be liked by the public. So at the end of the day what will matter is the public opinion of this new studio as well as the profitability for sustained success. Therefore, we are going to be filtering the information by this information as well since we would like the movie to do better than just "average".

# %%
tn_movie_budgets['release_year'].unique()
# Out:
# array([2009, 2011, 2019, 2015, 2017, 2018, 2007, 2012, 2013, 2010, 2016,
#        2014, 2006, 2008, 2005, 1997, 2004, 1999, 1995, 2003, 2001, 2020,
#        2002, 1998, 2000, 1991, 1994, 1996, 1993, 1992, 1988, 1990, 1989,
#        1978, 1981, 1984, 1982, 1985, 1980, 1963, 1987, 1986, 1983, 1979,
#        1977, 1970, 1969, 1976, 1965, 1962, 1964, 1959, 1966, 1974, 1956,
#        1975, 1973, 1960, 1967, 1968, 1971, 1951, 1972, 1961, 1946, 1944,
#        1953, 1954, 1957, 1952, 1930, 1939, 1925, 1950, 1948, 1958, 1943,
#        1940, 1945, 1947, 1938, 1927, 1949, 1955, 1936, 1937, 1941, 1942,
#        1933, 1935, 1931, 1916, 1929, 1934, 1915, 1920], dtype=int64)

# %%
tn_filtered = tn_movie_budgets[(tn_movie_budgets['profit %']>=25)&(tn_movie_budgets['release_year']>2008)]
tn_filtered
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# 5      6  Dec 18, 2015         Star Wars Ep. VII: The Force Awakens
# ...   ..           ...                                          ...
# 5685  86   Jul 7, 2017                                A Ghost Story
# 5717  18  Nov 12, 2010                               Tiny Furniture
# 5737  38  Mar 18, 2016                                       Krisha
# 5748  49   Sep 1, 2015                                       Exeter
# 5760  61   Apr 2, 2010                             Breaking Upwards
#
#       production_budget  domestic_gross  worldwide_gross      profit  \
# 0             425000000       760507625       2776345279  2351345279
# 1             410600000       241063875       1045663875   635063875
# 3             330600000       459005868       1403013963  1072413963
# 4             317000000       620181382       1316721747   999721747
# 5             306000000       936662225       2053311220  1747311220
# ...                 ...             ...              ...         ...
# 5685             100000         1594798          2769782     2669782
# 5717              50000          391674           424149      374149
# 5737              30000          144822           144822      114822
# 5748              25000               0           489792      464792
# 5760              15000          115592           115592      100592
#
#       profit % release_month  release_mo_num  release_year
# 0        553.0           Dec              12          2009
# 1        155.0           May               5          2011
# 3        324.0           May               5          2015
# 4        315.0           Dec              12          2017
# 5        571.0           Dec              12          2015
# ...        ...           ...             ...           ...
# 5685    2670.0           Jul               7          2017
# 5717     748.0           Nov              11          2010
# 5737     383.0           Mar               3          2016
# 5748    1859.0           Sep               9          2015
# 5760     671.0           Apr               4          2010
#
# [1363 rows x 11 columns]

# %%
merged_df = pd.merge(tn_filtered, tmdb_movies, how='left', left_on='movie', right_on='original_title')

# %%
merged_df.head()
# Out:
#    id_x release_date_x                                        movie  \
# 0     1   Dec 18, 2009                                       Avatar
# 1     2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2     4    May 1, 2015                      Avengers: Age of Ultron
# 3     5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# 4     6   Dec 18, 2015         Star Wars Ep. VII: The Force Awakens
#
#    production_budget  domestic_gross  worldwide_gross      profit  profit %  \
# 0          425000000       760507625       2776345279  2351345279     553.0
# 1          410600000       241063875       1045663875   635063875     155.0
# 2          330600000       459005868       1403013963  1072413963     324.0
# 3          317000000       620181382       1316721747   999721747     315.0
# 4          306000000       936662225       2053311220  1747311220     571.0
#
#   release_month  release_mo_num  ...          genre_ids     id_y  \
# 0           Dec              12  ...  [28, 12, 14, 878]  19995.0
# 1           May               5  ...       [12, 28, 14]   1865.0
# 2           May               5  ...      [28, 12, 878]  99861.0
# 3           Dec              12  ...                NaN      NaN
# 4           Dec              12  ...                NaN      NaN
#
#    original_language                               original_title popularity  \
# 0                 en                                       Avatar     26.526
# 1                 en  Pirates of the Caribbean: On Stranger Tides     30.579
# 2                 en                      Avengers: Age of Ultron     44.383
# 3                NaN                                          NaN        NaN
# 4                NaN                                          NaN        NaN
#
#    release_date_y                                        title vote_average  \
# 0      2009-12-18                                       Avatar          7.4
# 1      2011-05-20  Pirates of the Caribbean: On Stranger Tides          6.4
# 2      2015-05-01                      Avengers: Age of Ultron          7.3
# 3             NaN                                          NaN          NaN
# 4             NaN                                          NaN          NaN
#
#    vote_count  release_year_y
# 0     18676.0          2009.0
# 1      8571.0          2011.0
# 2     13457.0          2015.0
# 3         NaN             NaN
# 4         NaN             NaN
#
# [5 rows x 21 columns]

# %%
len(merged_df)
# Out:
# 1550

# %%
merged_df[merged_df['movie'].duplicated()]
# Out:
#       id_x release_date_x                         movie  production_budget  \
# 7        9   Nov 17, 2017                Justice League          300000000
# 9       10    Nov 6, 2015                       Spectre          300000000
# 31      39   May 14, 2010                    Robin Hood          210000000
# 33      42   Feb 16, 2018                 Black Panther          200000000
# 36      45   Dec 16, 2016  Rogue One: A Star Wars Story          200000000
# ...    ...            ...                           ...                ...
# 1524    60   Apr 23, 2009                          Home             500000
# 1531    72   Apr 28, 2017                       Sleight             250000
# 1535    10   Jul 20, 2012                          Burn             225000
# 1546    38   Mar 18, 2016                        Krisha              30000
# 1547    38   Mar 18, 2016                        Krisha              30000
#
#       domestic_gross  worldwide_gross      profit  profit % release_month  \
# 7          229024295        655945209   355945209     119.0           Nov
# 9          200074175        879620923   579620923     193.0           Nov
# 31         105487148        322459006   112459006      54.0           May
# 33         700059566       1348258224  1148258224     574.0           Feb
# 36         532177324       1049102856   849102856     425.0           Dec
# ...              ...              ...         ...       ...           ...
# 1524           15433         44793168    44293168    8859.0           Apr
# 1531         3930990          3934450     3684450    1474.0           Apr
# 1535         1109276          1109276      884276     393.0           Jul
# 1546          144822           144822      114822     383.0           Mar
# 1547          144822           144822      114822     383.0           Mar
#
#       release_mo_num  ...          genre_ids      id_y  original_language  \
# 7                 11  ...  [28, 12, 14, 878]  141052.0                 en
# 9                 11  ...       [28, 12, 80]  206647.0                 en
# 31                 5  ...       [12, 28, 53]  375588.0                 en
# 33                 2  ...  [28, 12, 14, 878]  284054.0                 en
# 36                12  ...      [28, 12, 878]  330459.0                 en
# ...              ...  ...                ...       ...                ...
# 1524               4  ...              [878]  496256.0                 en
# 1531               4  ...  [18, 53, 28, 878]  347882.0                 en
# 1535               7  ...               [99]  139948.0                 en
# 1546               3  ...               [18]  323929.0                 en
# 1547               3  ...               [18]  323929.0                 en
#
#                     original_title popularity  release_date_y  \
# 7                   Justice League     34.953      2017-11-17
# 9                          Spectre     30.318      2015-11-06
# 31                      Robin Hood     39.975      2018-11-21
# 33                   Black Panther     44.140      2018-02-16
# 36    Rogue One: A Star Wars Story     21.401      2016-12-16
# ...                            ...        ...             ...
# 1524                          Home      0.600      2017-04-30
# 1531                       Sleight      5.664      2017-04-28
# 1535                          Burn      1.958      2012-11-01
# 1546                        Krisha      5.288      2016-03-18
# 1547                        Krisha      5.288      2016-03-18
#
#                              title vote_average  vote_count  release_year_y
# 7                   Justice League          6.2      7510.0          2017.0
# 9                          Spectre          6.4      6719.0          2015.0
# 31                      Robin Hood          5.8      1194.0          2018.0
# 33                   Black Panther          7.4     12365.0          2018.0
# 36    Rogue One: A Star Wars Story          7.5      9296.0          2016.0
# ...                            ...          ...         ...             ...
# 1524                          Home          4.0         1.0          2017.0
# 1531                       Sleight          5.3       367.0          2017.0
# 1535                          Burn          7.1        14.0          2012.0
# 1546                        Krisha          6.8        86.0          2016.0
# 1547                        Krisha          6.8        86.0          2016.0
#
# [189 rows x 21 columns]

# %%
test = merged_df.drop_duplicates(keep='first')
test[test.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id_x, release_date_x, movie, production_budget, domestic_gross, worldwide_gross, profit, profit %, release_month, release_mo_num, release_year_x, genre_ids, id_y, original_language, original_title, popularity, release_date_y, title, vote_average, vote_count, release_year_y]
# Index: []
#
# [0 rows x 21 columns]

# %%
len(test)
# Out:
# 1446

# %%
test.isna().sum()
# Out:
# id_x                   0
# release_date_x         0
# movie                  0
# production_budget      0
# domestic_gross         0
# worldwide_gross        0
# profit                 0
# profit %               0
# release_month          0
# release_mo_num         0
# release_year_x         0
# genre_ids            331
# id_y                 331
# original_language    331
# original_title       331
# popularity           331
# release_date_y       331
# title                331
# vote_average         331
# vote_count           331
# release_year_y       331
# dtype: int64

# %%
imdb = pd.merge(imdb_title_basics, imdb_title_ratings, left_on='tconst', right_on='tconst')
imdb.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
len(imdb)
# Out:
# 73856

# %%
imdb.loc[imdb['start_year']>2008, 'averagerating']
# Out:
# 0        7.0
# 1        7.2
# 2        6.9
# 3        6.1
# 4        6.5
#         ...
# 73851    6.2
# 73852    8.7
# 73853    8.5
# 73854    6.6
# 73855    6.5
# Name: averagerating, Length: 73856, dtype: float64

# %%
imdb['averagerating'].agg('mean')
# Out:
# 6.332728552859619

# %%
imdb['averagerating'].agg('median')
# Out:
# 6.5

# %%
imdb['averagerating'].agg('mode')
# Out:
# 0    7.0
# dtype: float64

# %%
tn_filtered[tn_filtered.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, release_date, movie, production_budget, domestic_gross, worldwide_gross, profit, profit %, release_month, release_mo_num, release_year]
# Index: []

# %%
test2 = pd.merge(tn_filtered, imdb, left_on=['movie', 'release_year'], right_on=['original_title', 'start_year'])

# %%
test2[test2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, release_date, movie, production_budget, domestic_gross, worldwide_gross, profit, profit %, release_month, release_mo_num, release_year, tconst, primary_title, original_title, start_year, runtime_minutes, genres, averagerating, numvotes]
# Index: []

# %%
len(test2)
# Out:
# 983

# %%
imdb_tn_filtered = test2[test2['averagerating']>6.5]

# %%
imdb_tn_filtered.isna().sum()
# Out:
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# profit               0
# profit %             0
# release_month        0
# release_mo_num       0
# release_year         0
# tconst               0
# primary_title        0
# original_title       0
# start_year           0
# runtime_minutes      2
# genres               0
# averagerating        0
# numvotes             0
# dtype: int64

# %%
len(imdb_tn_filtered)
# Out:
# 493

# %%
imdb_tn_filtered.head()
# Out:
#    id  release_date                                        movie  \
# 0   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 1   4   May 1, 2015                      Avengers: Age of Ultron
# 2   7  Apr 27, 2018                       Avengers: Infinity War
# 4  10   Nov 6, 2015                                      Spectre
# 5  11  Jul 20, 2012                        The Dark Knight Rises
#
#    production_budget  domestic_gross  worldwide_gross      profit  profit %  \
# 0          410600000       241063875       1045663875   635063875     155.0
# 1          330600000       459005868       1403013963  1072413963     324.0
# 2          300000000       678815482       2048134200  1748134200     583.0
# 4          300000000       200074175        879620923   579620923     193.0
# 5          275000000       448139099       1084439099   809439099     294.0
#
#   release_month  release_mo_num  ...  \
# 0           May               5  ...
# 1           May               5  ...
# 2           Apr               4  ...
# 4           Nov              11  ...
# 5           Jul               7  ...
#
#                                 original_title start_year runtime_minutes  \
# 0  Pirates of the Caribbean: On Stranger Tides       2011           136.0
# 1                      Avengers: Age of Ultron       2015           141.0
# 2                       Avengers: Infinity War       2018           149.0
# 4                                      Spectre       2015           148.0
# 5                        The Dark Knight Rises       2012           164.0
#
#                           genres  averagerating  numvotes  genre1     genre2  \
# 0   [Action, Adventure, Fantasy]            6.6    447624  Action  Adventure
# 1    [Action, Adventure, Sci-Fi]            7.3    665594  Action  Adventure
# 2    [Action, Adventure, Sci-Fi]            8.5    670926  Action  Adventure
# 4  [Action, Adventure, Thriller]            6.8    352504  Action  Adventure
# 5             [Action, Thriller]            8.4   1387769  Action   Thriller
#
#      genre3       ROI %
# 0   Fantasy  254.667286
# 1    Sci-Fi  424.384139
# 2    Sci-Fi  682.711400
# 4  Thriller  293.206974
# 5       NaN  394.341491
#
# [5 rows x 23 columns]

# %%
medians = imdb_tn_filtered.groupby('release_month')['profit %'].median().reset_index()

# %%
medians
# Out:
#    release_month  profit %
# 0            Apr     327.0
# 1            Aug     131.5
# 2            Dec     254.5
# 3            Feb     286.0
# 4            Jan     167.0
# 5            Jul     349.0
# 6            Jun     399.5
# 7            Mar     383.0
# 8            May     240.0
# 9            Nov     315.5
# 10           Oct     301.0
# 11           Sep     230.0

# %%
sns.pointplot(data=medians, x='release_month', y='profit %', order=order)
# Out:
# <AxesSubplot:xlabel='release_month', ylabel='profit %'>

# %%
plt.scatter(x=imdb_tn_filtered['release_mo_num'], y=imdb_tn_filtered['profit %'])

# %%
medians = imdb_tn_filtered.groupby('release_month')['worldwide_gross'].median().reset_index()
medians.sort_values(by='worldwide_gross', ascending=False)
# Out:
#    release_month  worldwide_gross
# 8            May      393151347.0
# 6            Jun      243850259.5
# 3            Feb      203080161.0
# 7            Mar      155564919.0
# 9            Nov      155499543.5
# 5            Jul      144051623.0
# 2            Dec      141238660.5
# 0            Apr      116809717.0
# 11           Sep       96848720.5
# 4            Jan       82812456.0
# 10           Oct       77735925.0
# 1            Aug       70339015.5

# %%
with plt.style.context('seaborn-notebook'):
    fig, ax = plt.subplots(figsize=(10,5))
    sns.boxplot(x=imdb_tn_filtered['release_month'], y=imdb_tn_filtered['worldwide_gross'], order=order,
            showfliers=False, ax=ax, palette="light:#5A9_r")
    ax.set_xlabel('Release Month')
    ax.set_ylabel('Total Revenue ($)')
    sns.pointplot(data=medians, x='release_month', y='worldwide_gross', 
                  order=order, ax=ax, color='black');

# %%
fig, ax = plt.subplots(ncols=2, figsize=(15,5))
sns.pointplot(data=medians, x='release_month', y='worldwide_gross', order=order, ax=ax[0], color='orange')
ax[0].set_xlabel('Release Month')
ax[0].set_ylabel('Total Revenue')
sns.scatterplot(x=imdb_tn_filtered['release_month'], y=imdb_tn_filtered['worldwide_gross'], ax=ax[0])
sns.pointplot(data=medians, x='release_month', y='worldwide_gross', order=order, ax=ax[1], color='orange')
# Out:
# <AxesSubplot:xlabel='release_month', ylabel='worldwide_gross'>

# %%
plt.scatter(x=imdb_tn_filtered['release_mo_num'], y=imdb_tn_filtered['worldwide_gross'])

# %%
medians = imdb_tn_filtered.groupby('release_month')['profit'].median().reset_index()
medians
# Out:
#    release_month       profit
# 0            Apr  101373764.0
# 1            Aug   41006604.0
# 2            Dec   91838356.0
# 3            Feb  145580161.0
# 4            Jan   50131391.0
# 5            Jul  110187119.0
# 6            Jun  193322720.5
# 7            Mar  110724600.0
# 8            May  267769200.0
# 9            Nov  118389547.0
# 10           Oct   42150788.0
# 11           Sep   56731236.5

# %%
with plt.style.context('seaborn-notebook'):
    fig, ax = plt.subplots(figsize=(10,5))
    sns.boxplot(x=imdb_tn_filtered['release_month'], y=imdb_tn_filtered['profit'], 
            order=order, showfliers=False, ax=ax, palette="viridis")
    sns.pointplot(data=medians, x='release_month', y='profit', order=order, ax=ax, color='black')
    ax.set_xlabel('Release Month')
    ax.set_ylabel('Total Profit ($)');

# %%
plt.scatter(x=imdb_tn_filtered['release_mo_num'], y=imdb_tn_filtered['profit'])

# %%
sns.scatterplot(x=imdb_tn_filtered['release_mo_num'], y=imdb_tn_filtered['profit'])
# Out:
# <AxesSubplot:xlabel='release_mo_num', ylabel='profit'>

# %% [markdown]
# # Genre vs. Revenue / Genre vs. Profit

# %%
len(imdb[(imdb['start_year']>2010)])
# Out:
# 67064

# %%
len(tn_movie_budgets)
# Out:
# 5782

# %%
len(bom_movie_gross)
# Out:
# 3387

# %% [markdown]
# ### IMDBk Testing

# %%
imdb_movies_k = pd.read_csv('IMDb movies.csv')
# Out:
# C:\Users\berke\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
imdb_movies_k['year'].replace('TV Movie 2019', '2019', inplace=True)

# %%
imdb_movies_k['year'] =imdb_movies_k['year'].astype('int64')

# %%
imdb_movies_k.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes   budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154      NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %%
filtered_imdbk = imdb_movies_k[(imdb_movies_k['year']>2010) & (imdb_movies_k['year']!=2020) & (imdb_movies_k['year']<=2021)]

# %%
len(filtered_imdbk)
# Out:
# 26257

# %%
filtered_imdbk['genre'] = filtered_imdbk['genre'].map(lambda x: x.split(','))
filtered_imdbk.head()
# Out:
# <ipython-input-462-7914b06d2c99>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_imdbk['genre'] = filtered_imdbk['genre'].map(lambda x: x.split(','))
#       imdb_title_id                     title              original_title  \
# 15675     tt0069049  L'altra faccia del vento  The Other Side of the Wind
# 25479     tt0100275     La Telenovela Errante       La Telenovela Errante
# 32465     tt0137204           Joe Finds Grace             Joe Finds Grace
# 34658     tt0176694       Az ember tragédiája         Az ember tragédiája
# 38237     tt0249516                Foodfight!                  Foodfight!
#
#        year date_published                             genre  duration  \
# 15675  2018     2018-11-02                           [Drama]       122
# 25479  2017     2018-09-06        [Comedy,  Drama,  Fantasy]        80
# 32465  2017     2018-03-20  [Animation,  Adventure,  Comedy]        83
# 34658  2011     2011-12-08     [Animation,  Drama,  History]       160
# 38237  2011     2013-02-12  [Animation,  Action,  Adventure]        91
#
#                  country         language                       director  ...  \
# 15675  France, Iran, USA  English, German                   Orson Welles  ...
# 25479              Chile          Spanish  Raoul Ruiz, Valeria Sarmiento  ...
# 32465             Canada          English               Anthony Harrison  ...
# 34658            Hungary        Hungarian              Marcell Jankovics  ...
# 38237                USA          English              Lawrence Kasanoff  ...
#
#                                                   actors  \
# 15675  John Huston, Oja Kodar, Peter Bogdanovich, Sus...
# 25479  Luis Alarcón, Patricia Rivadeneira, Francisco ...
# 32465  Anthony Harrison, C. Ernst Harth, Ellie Harvie...
# 34658  Gyula Balázsi, Péter Benkö, Ágnes Bertalan, Pé...
# 38237  Charlie Sheen, Hilary Duff, Eva Longoria, Wayn...
#
#                                              description avg_vote votes  \
# 15675  A Hollywood director emerges from semi-exile w...      6.8  5887
# 25479  The film revolves around the concept of soap o...      6.6   260
# 32465  Simple-minded Joseph Briteman breaks a golden ...      8.8   264
# 34658  Adam's and Eve's epic journey throughout histo...      7.9   682
# 38237  The evil Brand X joins a supermarket that beco...      1.5  9183
#
#            budget  usa_gross_income worlwide_gross_income metascore  \
# 15675         NaN               NaN                   NaN      78.0
# 25479         NaN            $ 3624                $ 3624       NaN
# 32465         NaN               NaN                   NaN       NaN
# 34658         NaN               NaN                   NaN       NaN
# 38237  $ 65000000               NaN              $ 120141       NaN
#
#       reviews_from_users  reviews_from_critics
# 15675               81.0                  98.0
# 25479                NaN                  27.0
# 32465                2.0                   NaN
# 34658                2.0                   4.0
# 38237              129.0                  15.0
#
# [5 rows x 22 columns]

# %%
filtered_imdbk['genre'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1709, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [Drama]                           4055
# [Comedy]                          2290
# [Comedy,  Drama]                  1459
# [Horror]                           923
# [Drama,  Romance]                  887
#                                   ...
# [Biography,  Family,  History]       1
# [Crime,  Horror,  Romance]           1
# [Comedy,  Crime,  Western]           1
# [Sport,  Thriller]                   1
# [Family,  Sci-Fi,  Thriller]         1
# Name: genre, Length: 594, dtype: int64

# %%
filtered_imdbk['genre1'] = filtered_imdbk['genre'].map(lambda x: x[0])
filtered_imdbk['genre2'] = filtered_imdbk['genre'].map(lambda x: x[1].strip() if (len(x)>=2) else np.NaN)
# Out:
# <ipython-input-464-ab28a84c3a17>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_imdbk['genre1'] = filtered_imdbk['genre'].map(lambda x: x[0])
# <ipython-input-464-ab28a84c3a17>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_imdbk['genre2'] = filtered_imdbk['genre'].map(lambda x: x[1].strip() if (len(x)>=2) else np.NaN)

# %%
filtered_imdbk['genre3'] = filtered_imdbk['genre'].map(lambda x: x[2].strip() if (len(x)==3) else np.NaN)
# Out:
# <ipython-input-465-ce51a6311d6f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_imdbk['genre3'] = filtered_imdbk['genre'].map(lambda x: x[2].strip() if (len(x)==3) else np.NaN)

# %%
len(filtered_imdbk)
# Out:
# 26257

# %%
filtered_imdbk.tail()
# Out:
#       imdb_title_id                       title              original_title  \
# 85848     tt9905462                   Pengalila                   Pengalila
# 85849     tt9906644                   Manoharam                   Manoharam
# 85852     tt9911774   Padmavyuhathile Abhimanyu   Padmavyuhathile Abhimanyu
# 85853     tt9914286           Sokagin Çocuklari           Sokagin Çocuklari
# 85854     tt9914942  La vida sense la Sara Amat  La vida sense la Sara Amat
#
#        year date_published             genre  duration country   language  \
# 85848  2019     2019-03-08           [Drama]       111   India  Malayalam
# 85849  2019     2019-09-27  [Comedy,  Drama]       122   India  Malayalam
# 85852  2019     2019-03-08           [Drama]       130   India  Malayalam
# 85853  2019     2019-03-15  [Drama,  Family]        98  Turkey    Turkish
# 85854  2019     2020-02-05           [Drama]        74   Spain    Catalan
#
#                 director  ... votes        budget usa_gross_income  \
# 85848      T.V. Chandran  ...   553  INR 10000000              NaN
# 85849        Anvar Sadik  ...   491           NaN              NaN
# 85852    Vineesh Aaradya  ...   265           NaN              NaN
# 85853  Ahmet Faik Akinci  ...   194           NaN              NaN
# 85854          Laura Jou  ...   102           NaN              NaN
#
#       worlwide_gross_income  metascore  reviews_from_users  \
# 85848                   NaN        NaN                 NaN
# 85849                   NaN        NaN                 9.0
# 85852                   NaN        NaN                 NaN
# 85853                $ 2833        NaN                 NaN
# 85854               $ 59794        NaN                 NaN
#
#       reviews_from_critics  genre1  genre2  genre3
# 85848                  NaN   Drama     NaN     NaN
# 85849                  1.0  Comedy   Drama     NaN
# 85852                  NaN   Drama     NaN     NaN
# 85853                  NaN   Drama  Family     NaN
# 85854                  2.0   Drama     NaN     NaN
#
# [5 rows x 25 columns]

# %%
genre1_counts = {}

for genre in filtered_imdbk['genre1']:
    if genre not in genre1_counts.keys():
        genre1_counts[genre]=1
    else:
        genre1_counts[genre]+=1
    
genre2_counts = {}

for genre in filtered_imdbk['genre2']:
    if genre not in genre2_counts.keys():
        genre2_counts[genre]=1
    else:
        genre2_counts[genre]+=1
        
genre3_counts = {}

for genre in filtered_imdbk['genre3']:
    if genre not in genre3_counts.keys():
        genre3_counts[genre]=1
    else:
        genre3_counts[genre]+=1
        
print(genre1_counts, genre2_counts, genre3_counts)
# Out:
# {'Drama': 7923, 'Comedy': 7110, 'Animation': 895, 'Biography': 764, 'Thriller': 585, 'Action': 3797, 'Adventure': 763, 'Horror': 2071, 'Crime': 1295, 'Mystery': 176, 'Sci-Fi': 136, 'Fantasy': 172, 'Family': 194, 'Music': 19, 'Western': 37, 'Romance': 229, 'Musical': 37, 'War': 12, 'Sport': 12, 'History': 29, 'Documentary': 1} {nan: 8944, 'Drama': 5228, 'Adventure': 1057, 'Action': 249, 'Comedy': 1076, 'Crime': 1059, 'Horror': 1272, 'Sci-Fi': 484, 'Family': 643, 'Thriller': 1798, 'Mystery': 936, 'Fantasy': 511, 'Romance': 1913, 'History': 337, 'War': 135, 'Biography': 116, 'Music': 203, 'Sport': 151, 'Musical': 106, 'Western': 38, 'News': 1} {nan: 17086, 'Fantasy': 430, 'Comedy': 431, 'History': 334, 'Adventure': 146, 'Drama': 1057, 'Romance': 1403, 'Thriller': 2219, 'Sci-Fi': 556, 'Mystery': 645, 'Music': 178, 'Horror': 461, 'War': 216, 'Sport': 192, 'Western': 51, 'Crime': 263, 'Family': 487, 'Musical': 92, 'Biography': 10}

# %%
#code snippet from https://www.geeksforgeeks.org/python-combine-two-dictionary-adding-values-for-common-keys/ (Method #3)
import itertools
import collections

total_genre = collections.defaultdict(int)
for key, val in itertools.chain(genre1_counts.items(), genre2_counts.items()):
    total_genre[key] += val
       
total_genre
# Out:
# defaultdict(int,
#             {'Drama': 13151,
#              'Comedy': 8186,
#              'Animation': 895,
#              'Biography': 880,
#              'Thriller': 2383,
#              'Action': 4046,
#              'Adventure': 1820,
#              'Horror': 3343,
#              'Crime': 2354,
#              'Mystery': 1112,
#              'Sci-Fi': 620,
#              'Fantasy': 683,
#              'Family': 837,
#              'Music': 222,
#              'Western': 75,
#              'Romance': 2142,
#              'Musical': 143,
#              'War': 147,
#              'Sport': 163,
#              'History': 366,
#              'Documentary': 1,
#              nan: 8944,
#              'News': 1})

# %%
#code snippet from https://www.geeksforgeeks.org/python-combine-two-dictionary-adding-values-for-common-keys/ (Method #3)
total_genre_counts = collections.defaultdict(int)
for key, val in itertools.chain(total_genre.items(), genre3_counts.items()):
    total_genre_counts[key] += val
total_genre_counts
# Out:
# defaultdict(int,
#             {'Drama': 14208,
#              'Comedy': 8617,
#              'Animation': 895,
#              'Biography': 890,
#              'Thriller': 4602,
#              'Action': 4046,
#              'Adventure': 1966,
#              'Horror': 3804,
#              'Crime': 2617,
#              'Mystery': 1757,
#              'Sci-Fi': 1176,
#              'Fantasy': 1113,
#              'Family': 1324,
#              'Music': 400,
#              'Western': 126,
#              'Romance': 3545,
#              'Musical': 235,
#              'War': 363,
#              'Sport': 355,
#              'History': 700,
#              'Documentary': 1,
#              nan: 26030,
#              'News': 1})

# %%
del total_genre_counts[np.nan]
total_genre_counts
# Out:
# defaultdict(int,
#             {'Drama': 14208,
#              'Comedy': 8617,
#              'Animation': 895,
#              'Biography': 890,
#              'Thriller': 4602,
#              'Action': 4046,
#              'Adventure': 1966,
#              'Horror': 3804,
#              'Crime': 2617,
#              'Mystery': 1757,
#              'Sci-Fi': 1176,
#              'Fantasy': 1113,
#              'Family': 1324,
#              'Music': 400,
#              'Western': 126,
#              'Romance': 3545,
#              'Musical': 235,
#              'War': 363,
#              'Sport': 355,
#              'History': 700,
#              'Documentary': 1,
#              'News': 1})

# %%
# dict(total_genre_counts)
# list(total_genre_counts.values())
# test = {}
# for k,v in total_genre_counts.items():
#     test[k] = str(v)

# values = list(test.values())
# keys = list(test.keys())


# list(total_genre_counts.values())

# %%
#code snippet from https://stackoverflow.com/questions/613183/how-do-i-sort-a-dictionary-by-value
total_genre_counts={k: v for k, v in sorted(total_genre_counts.items(), key=lambda item: item[1])}
total_genre_counts
# Out:
# {'Documentary': 1,
#  'News': 1,
#  'Western': 126,
#  'Musical': 235,
#  'Sport': 355,
#  'War': 363,
#  'Music': 400,
#  'History': 700,
#  'Biography': 890,
#  'Animation': 895,
#  'Fantasy': 1113,
#  'Sci-Fi': 1176,
#  'Family': 1324,
#  'Mystery': 1757,
#  'Adventure': 1966,
#  'Crime': 2617,
#  'Romance': 3545,
#  'Horror': 3804,
#  'Action': 4046,
#  'Thriller': 4602,
#  'Comedy': 8617,
#  'Drama': 14208}

# %%
fig, ax = plt.subplots()
ax.barh(y=list(total_genre_counts.keys()), width=list(total_genre_counts.values()))
ax.set_xlabel('Number of Movies')
ax.set_ylabel('Genre')
ax.set_title('Most Produced Movie Genres between 2010 and 2021'); #we excluded 2020 but maybe we shouldn't?

# %% [markdown]
# ### Testing to see if I can use IMDb_k dataset for financial information

# %%
usa_imdbk = filtered_imdbk[filtered_imdbk['country']=='USA']

# %%
print(len(usa_imdbk))
usa_imdbk.isna().sum()
# Out:
# 7178
# imdb_title_id               0
# title                       0
# original_title              0
# year                        0
# date_published              0
# genre                       0
# duration                    0
# country                     0
# language                  175
# director                   18
# writer                     79
# production_company        439
# actors                     15
# description                 9
# avg_vote                    0
# votes                       0
# budget                   4589
# usa_gross_income         5466
# worlwide_gross_income    5057
# metascore                4876
# reviews_from_users        160
# reviews_from_critics      701
# genre1                      0
# genre2                   2204
# genre3                   4368
# dtype: int64

# %%
filtered_imdbk[filtered_imdbk['worlwide_gross_income'].isna()]
# Out:
#       imdb_title_id                      title              original_title  \
# 15675     tt0069049   L'altra faccia del vento  The Other Side of the Wind
# 32465     tt0137204            Joe Finds Grace             Joe Finds Grace
# 34658     tt0176694        Az ember tragédiája         Az ember tragédiája
# 38617     tt0255820          Return to Babylon           Return to Babylon
# 40227     tt0285252             Life's a Beach              Life's a Beach
# ...             ...                        ...                         ...
# 85844     tt9903716                     Jessie                      Jessie
# 85845     tt9904250   La reina de los lagartos    La reina de los lagartos
# 85848     tt9905462                  Pengalila                   Pengalila
# 85849     tt9906644                  Manoharam                   Manoharam
# 85852     tt9911774  Padmavyuhathile Abhimanyu   Padmavyuhathile Abhimanyu
#
#        year date_published                             genre  duration  \
# 15675  2018     2018-11-02                           [Drama]       122
# 32465  2017     2018-03-20  [Animation,  Adventure,  Comedy]        83
# 34658  2011     2011-12-08     [Animation,  Drama,  History]       160
# 38617  2013     2013-08-11      [Biography,  Comedy,  Drama]        75
# 40227  2012     2012-05-22                          [Comedy]       100
# ...     ...            ...                               ...       ...
# 85844  2019     2019-03-15               [Horror,  Thriller]       106
# 85845  2019     2019-10-05                         [Fantasy]        63
# 85848  2019     2019-03-08                           [Drama]       111
# 85849  2019     2019-09-27                  [Comedy,  Drama]       122
# 85852  2019     2019-03-08                           [Drama]       130
#
#                  country          language                       director  \
# 15675  France, Iran, USA   English, German                   Orson Welles
# 32465             Canada           English               Anthony Harrison
# 34658            Hungary         Hungarian              Marcell Jankovics
# 38617                USA           English            Alex Monty Canawati
# 40227                USA           English                    Tony Vitale
# ...                  ...               ...                            ...
# 85844              India            Telugu                Aswani Kumar V.
# 85845                NaN  Spanish, Catalan  Juan González, Nando Martínez
# 85848              India         Malayalam                  T.V. Chandran
# 85849              India         Malayalam                    Anvar Sadik
# 85852              India         Malayalam                Vineesh Aaradya
#
#        ... votes        budget usa_gross_income worlwide_gross_income  \
# 15675  ...  5887           NaN              NaN                   NaN
# 32465  ...   264           NaN              NaN                   NaN
# 34658  ...   682           NaN              NaN                   NaN
# 38617  ...   144     $ 2000000              NaN                   NaN
# 40227  ...   226     $ 4000000              NaN                   NaN
# ...    ...   ...           ...              ...                   ...
# 85844  ...   318           NaN              NaN                   NaN
# 85845  ...   103           NaN              NaN                   NaN
# 85848  ...   553  INR 10000000              NaN                   NaN
# 85849  ...   491           NaN              NaN                   NaN
# 85852  ...   265           NaN              NaN                   NaN
#
#        metascore  reviews_from_users reviews_from_critics     genre1  \
# 15675       78.0                81.0                 98.0      Drama
# 32465        NaN                 2.0                  NaN  Animation
# 34658        NaN                 2.0                  4.0  Animation
# 38617        NaN                 1.0                  3.0  Biography
# 40227        NaN                 3.0                  1.0     Comedy
# ...          ...                 ...                  ...        ...
# 85844        NaN                27.0                  NaN     Horror
# 85845        NaN                 NaN                  5.0    Fantasy
# 85848        NaN                 NaN                  NaN      Drama
# 85849        NaN                 9.0                  1.0     Comedy
# 85852        NaN                 NaN                  NaN      Drama
#
#           genre2   genre3
# 15675        NaN      NaN
# 32465  Adventure   Comedy
# 34658      Drama  History
# 38617     Comedy    Drama
# 40227        NaN      NaN
# ...          ...      ...
# 85844   Thriller      NaN
# 85845        NaN      NaN
# 85848        NaN      NaN
# 85849      Drama      NaN
# 85852        NaN      NaN
#
# [12673 rows x 25 columns]

# %% [markdown]
# It doesn't seem like a viable option. Too many data point missing from finances

# %% [markdown]
# ### Checking imdb_tn_filtered dataset to see if I have all the info I need

# %%
imdb_tn_filtered.head()
# Out:
#    id  release_date                                        movie  \
# 0   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 1   4   May 1, 2015                      Avengers: Age of Ultron
# 2   7  Apr 27, 2018                       Avengers: Infinity War
# 4  10   Nov 6, 2015                                      Spectre
# 5  11  Jul 20, 2012                        The Dark Knight Rises
#
#    production_budget  domestic_gross  worldwide_gross      profit  profit %  \
# 0          410600000       241063875       1045663875   635063875     155.0
# 1          330600000       459005868       1403013963  1072413963     324.0
# 2          300000000       678815482       2048134200  1748134200     583.0
# 4          300000000       200074175        879620923   579620923     193.0
# 5          275000000       448139099       1084439099   809439099     294.0
#
#   release_month  release_mo_num  release_year     tconst  \
# 0           May               5          2011  tt1298650
# 1           May               5          2015  tt2395427
# 2           Apr               4          2018  tt4154756
# 4           Nov              11          2015  tt2379713
# 5           Jul               7          2012  tt1345836
#
#                                  primary_title  \
# 0  Pirates of the Caribbean: On Stranger Tides
# 1                      Avengers: Age of Ultron
# 2                       Avengers: Infinity War
# 4                                      Spectre
# 5                        The Dark Knight Rises
#
#                                 original_title  start_year  runtime_minutes  \
# 0  Pirates of the Caribbean: On Stranger Tides        2011            136.0
# 1                      Avengers: Age of Ultron        2015            141.0
# 2                       Avengers: Infinity War        2018            149.0
# 4                                      Spectre        2015            148.0
# 5                        The Dark Knight Rises        2012            164.0
#
#                       genres  averagerating  numvotes
# 0   Action,Adventure,Fantasy            6.6    447624
# 1    Action,Adventure,Sci-Fi            7.3    665594
# 2    Action,Adventure,Sci-Fi            8.5    670926
# 4  Action,Adventure,Thriller            6.8    352504
# 5            Action,Thriller            8.4   1387769

# %%
imdb_tn_filtered.loc[imdb_tn_filtered['genres'].isna(), :]
# Out:
# Empty DataFrame
# Columns: [id, release_date, movie, production_budget, domestic_gross, worldwide_gross, profit, profit %, release_month, release_mo_num, release_year, tconst, primary_title, original_title, start_year, runtime_minutes, genres, averagerating, numvotes]
# Index: []

# %%
imdb_tn_filtered.isna().sum()
# Out:
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# profit               0
# profit %             0
# release_month        0
# release_mo_num       0
# release_year         0
# tconst               0
# primary_title        0
# original_title       0
# start_year           0
# runtime_minutes      2
# genres               0
# averagerating        0
# numvotes             0
# dtype: int64

# %%
imdb_tn_filtered['genres'].dtype
# Out:
# dtype('O')

# %%
imdb_tn_filtered['genres'] = imdb_tn_filtered['genres'].map(lambda x: x.strip().split(','))
imdb_tn_filtered.head()
# Out:
# <ipython-input-487-048b0847e17d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_tn_filtered['genres'] = imdb_tn_filtered['genres'].map(lambda x: x.strip().split(','))
#    id  release_date                                        movie  \
# 0   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 1   4   May 1, 2015                      Avengers: Age of Ultron
# 2   7  Apr 27, 2018                       Avengers: Infinity War
# 4  10   Nov 6, 2015                                      Spectre
# 5  11  Jul 20, 2012                        The Dark Knight Rises
#
#    production_budget  domestic_gross  worldwide_gross      profit  profit %  \
# 0          410600000       241063875       1045663875   635063875     155.0
# 1          330600000       459005868       1403013963  1072413963     324.0
# 2          300000000       678815482       2048134200  1748134200     583.0
# 4          300000000       200074175        879620923   579620923     193.0
# 5          275000000       448139099       1084439099   809439099     294.0
#
#   release_month  release_mo_num  release_year     tconst  \
# 0           May               5          2011  tt1298650
# 1           May               5          2015  tt2395427
# 2           Apr               4          2018  tt4154756
# 4           Nov              11          2015  tt2379713
# 5           Jul               7          2012  tt1345836
#
#                                  primary_title  \
# 0  Pirates of the Caribbean: On Stranger Tides
# 1                      Avengers: Age of Ultron
# 2                       Avengers: Infinity War
# 4                                      Spectre
# 5                        The Dark Knight Rises
#
#                                 original_title  start_year  runtime_minutes  \
# 0  Pirates of the Caribbean: On Stranger Tides        2011            136.0
# 1                      Avengers: Age of Ultron        2015            141.0
# 2                       Avengers: Infinity War        2018            149.0
# 4                                      Spectre        2015            148.0
# 5                        The Dark Knight Rises        2012            164.0
#
#                           genres  averagerating  numvotes
# 0   [Action, Adventure, Fantasy]            6.6    447624
# 1    [Action, Adventure, Sci-Fi]            7.3    665594
# 2    [Action, Adventure, Sci-Fi]            8.5    670926
# 4  [Action, Adventure, Thriller]            6.8    352504
# 5             [Action, Thriller]            8.4   1387769

# %% [markdown]
# I need to check to make sure that one movie doesn't have more than 3 genres at the same time since my code is geared towards that.

# %%
for x in imdb_tn_filtered['genres']:
    if len(x)>3:
        print(len(x))

# %%
imdb_tn_filtered['genre1'] = imdb_tn_filtered['genres'].map(lambda x: x[0].strip())
imdb_tn_filtered['genre2'] = imdb_tn_filtered['genres'].map(lambda x: x[1].strip() if (len(x)>=2) else np.NaN)
imdb_tn_filtered['genre3'] = imdb_tn_filtered['genres'].map(lambda x: x[2].strip() if (len(x)==3) else np.NaN)
# Out:
# <ipython-input-489-b72c3f5e9305>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_tn_filtered['genre1'] = imdb_tn_filtered['genres'].map(lambda x: x[0].strip())
# <ipython-input-489-b72c3f5e9305>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_tn_filtered['genre2'] = imdb_tn_filtered['genres'].map(lambda x: x[1].strip() if (len(x)>=2) else np.NaN)
# <ipython-input-489-b72c3f5e9305>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_tn_filtered['genre3'] = imdb_tn_filtered['genres'].map(lambda x: x[2].strip() if (len(x)==3) else np.NaN)

# %%
genre1_counts = {}

for genre in imdb_tn_filtered['genre1']:
    if genre not in genre1_counts.keys():
        genre1_counts[genre]=1
    else:
        genre1_counts[genre]+=1
    
genre2_counts = {}

for genre in imdb_tn_filtered['genre2']:
    if genre not in genre2_counts.keys():
        genre2_counts[genre]=1
    else:
        genre2_counts[genre]+=1
        
genre3_counts = {}

for genre in imdb_tn_filtered['genre3']:
    if genre not in genre3_counts.keys():
        genre3_counts[genre]=1
    else:
        genre3_counts[genre]+=1
        
print(genre1_counts, genre2_counts, genre3_counts)
# Out:
# {'Action': 154, 'Adventure': 65, 'Drama': 92, 'Horror': 8, 'Family': 1, 'Comedy': 70, 'Biography': 59, 'Crime': 25, 'Animation': 5, 'Mystery': 3, 'Romance': 1, 'Thriller': 1, 'Documentary': 9} {'Adventure': 84, 'Thriller': 18, 'Animation': 36, 'Family': 10, 'Fantasy': 11, 'Crime': 41, 'Romance': 27, 'Mystery': 21, 'Comedy': 39, 'Sci-Fi': 11, 'Drama': 129, nan: 33, 'Western': 1, 'History': 3, 'Biography': 10, 'Sport': 3, 'Horror': 5, 'War': 2, 'Music': 6, 'Documentary': 3} {'Fantasy': 21, 'Sci-Fi': 46, 'Thriller': 52, nan: 139, 'Comedy': 47, 'Drama': 58, 'Animation': 14, 'Horror': 3, 'Family': 20, 'Musical': 3, 'History': 15, 'Biography': 3, 'Crime': 11, 'Mystery': 11, 'Western': 2, 'War': 3, 'Sport': 11, 'Music': 6, 'Romance': 27, 'Documentary': 1}

# %%
#code snippet from https://www.geeksforgeeks.org/python-combine-two-dictionary-adding-values-for-common-keys/ (Method #3)
import itertools
import collections

total_genre = collections.defaultdict(int)
for key, val in itertools.chain(genre1_counts.items(), genre2_counts.items()):
    total_genre[key] += val
       
total_genre
# Out:
# defaultdict(int,
#             {'Action': 154,
#              'Adventure': 149,
#              'Drama': 221,
#              'Horror': 13,
#              'Family': 11,
#              'Comedy': 109,
#              'Biography': 69,
#              'Crime': 66,
#              'Animation': 41,
#              'Mystery': 24,
#              'Romance': 28,
#              'Thriller': 19,
#              'Documentary': 12,
#              'Fantasy': 11,
#              'Sci-Fi': 11,
#              nan: 33,
#              'Western': 1,
#              'History': 3,
#              'Sport': 3,
#              'War': 2,
#              'Music': 6})

# %%
#code snippet from https://www.geeksforgeeks.org/python-combine-two-dictionary-adding-values-for-common-keys/ (Method #3)
total_genre_counts = collections.defaultdict(int)
for key, val in itertools.chain(total_genre.items(), genre3_counts.items()):
    total_genre_counts[key] += val
total_genre_counts
del total_genre_counts[np.nan]

# %%
#code snippet from https://stackoverflow.com/questions/613183/how-do-i-sort-a-dictionary-by-value
total_genre_counts={k: v for k, v in sorted(total_genre_counts.items(), key=lambda item: item[1], reverse=True)}
total_genre_counts
# Out:
# {'Drama': 279,
#  'Comedy': 156,
#  'Action': 154,
#  'Adventure': 149,
#  'Crime': 77,
#  'Biography': 72,
#  'Thriller': 71,
#  'Sci-Fi': 57,
#  'Animation': 55,
#  'Romance': 55,
#  'Mystery': 35,
#  'Fantasy': 32,
#  'Family': 31,
#  'History': 18,
#  'Horror': 16,
#  'Sport': 14,
#  'Documentary': 13,
#  'Music': 12,
#  'War': 5,
#  'Western': 3,
#  'Musical': 3}

# %%
with plt.style.context('seaborn-notebook'):
    fig, ax = plt.subplots(figsize=(15,5))
    sns.barplot(x=list(total_genre_counts.values()), y= list(total_genre_counts.keys()), orient='h', palette='viridis')
# ax.barh(y=list(total_genre_counts.keys()), width=list(total_genre_counts.values()), color='Green')
    ax.set_xlabel('Number of Movies')
    ax.set_ylabel('Genre')
    ax.set_title('Most Produced Movie Genres between 2009 and 2019'); #we excluded 2020 but maybe we shouldn't?

# %%
imdb_tn_filtered.head()
# Out:
#    id  release_date                                        movie  \
# 0   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 1   4   May 1, 2015                      Avengers: Age of Ultron
# 2   7  Apr 27, 2018                       Avengers: Infinity War
# 4  10   Nov 6, 2015                                      Spectre
# 5  11  Jul 20, 2012                        The Dark Knight Rises
#
#    production_budget  domestic_gross  worldwide_gross      profit  profit %  \
# 0          410600000       241063875       1045663875   635063875     155.0
# 1          330600000       459005868       1403013963  1072413963     324.0
# 2          300000000       678815482       2048134200  1748134200     583.0
# 4          300000000       200074175        879620923   579620923     193.0
# 5          275000000       448139099       1084439099   809439099     294.0
#
#   release_month  release_mo_num  ...  \
# 0           May               5  ...
# 1           May               5  ...
# 2           Apr               4  ...
# 4           Nov              11  ...
# 5           Jul               7  ...
#
#                                  primary_title  \
# 0  Pirates of the Caribbean: On Stranger Tides
# 1                      Avengers: Age of Ultron
# 2                       Avengers: Infinity War
# 4                                      Spectre
# 5                        The Dark Knight Rises
#
#                                 original_title start_year runtime_minutes  \
# 0  Pirates of the Caribbean: On Stranger Tides       2011           136.0
# 1                      Avengers: Age of Ultron       2015           141.0
# 2                       Avengers: Infinity War       2018           149.0
# 4                                      Spectre       2015           148.0
# 5                        The Dark Knight Rises       2012           164.0
#
#                           genres  averagerating numvotes  genre1     genre2  \
# 0   [Action, Adventure, Fantasy]            6.6   447624  Action  Adventure
# 1    [Action, Adventure, Sci-Fi]            7.3   665594  Action  Adventure
# 2    [Action, Adventure, Sci-Fi]            8.5   670926  Action  Adventure
# 4  [Action, Adventure, Thriller]            6.8   352504  Action  Adventure
# 5             [Action, Thriller]            8.4  1387769  Action   Thriller
#
#      genre3
# 0   Fantasy
# 1    Sci-Fi
# 2    Sci-Fi
# 4  Thriller
# 5       NaN
#
# [5 rows x 22 columns]

# %%
exploded_imdb_tn = imdb_tn_filtered.explode('genres')
exploded_imdb_tn.head()
# Out:
#    id  release_date                                        movie  \
# 0   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 0   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 0   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 1   4   May 1, 2015                      Avengers: Age of Ultron
# 1   4   May 1, 2015                      Avengers: Age of Ultron
#
#    production_budget  domestic_gross  worldwide_gross      profit  profit %  \
# 0          410600000       241063875       1045663875   635063875     155.0
# 0          410600000       241063875       1045663875   635063875     155.0
# 0          410600000       241063875       1045663875   635063875     155.0
# 1          330600000       459005868       1403013963  1072413963     324.0
# 1          330600000       459005868       1403013963  1072413963     324.0
#
#   release_month  release_mo_num  ...  \
# 0           May               5  ...
# 0           May               5  ...
# 0           May               5  ...
# 1           May               5  ...
# 1           May               5  ...
#
#                                  primary_title  \
# 0  Pirates of the Caribbean: On Stranger Tides
# 0  Pirates of the Caribbean: On Stranger Tides
# 0  Pirates of the Caribbean: On Stranger Tides
# 1                      Avengers: Age of Ultron
# 1                      Avengers: Age of Ultron
#
#                                 original_title start_year runtime_minutes  \
# 0  Pirates of the Caribbean: On Stranger Tides       2011           136.0
# 0  Pirates of the Caribbean: On Stranger Tides       2011           136.0
# 0  Pirates of the Caribbean: On Stranger Tides       2011           136.0
# 1                      Avengers: Age of Ultron       2015           141.0
# 1                      Avengers: Age of Ultron       2015           141.0
#
#       genres  averagerating numvotes  genre1     genre2   genre3
# 0     Action            6.6   447624  Action  Adventure  Fantasy
# 0  Adventure            6.6   447624  Action  Adventure  Fantasy
# 0    Fantasy            6.6   447624  Action  Adventure  Fantasy
# 1     Action            7.3   665594  Action  Adventure   Sci-Fi
# 1  Adventure            7.3   665594  Action  Adventure   Sci-Fi
#
# [5 rows x 22 columns]

# %%
exploded_imdb_tn.drop(exploded_imdb_tn[exploded_imdb_tn['movie'] == 'Beauty and the Beast'].index, inplace=True)

# %%
exploded_imdb_tn['genres']=exploded_imdb_tn['genres'].map(lambda x: x.strip())

# %% [markdown]
# ### Genre vs. Revenue

# %%
genre_revenue_order = exploded_imdb_tn.groupby('genres').median()['worldwide_gross'].sort_values(ascending=False).index

# %%
with plt.style.context('seaborn-notebook'):
    fig, ax = plt.subplots(figsize=(15,5))
    sns.barplot(x=exploded_imdb_tn['genres'], y=exploded_imdb_tn['worldwide_gross'], estimator=np.median, ci=None, order=genre_revenue_order, palette="dark:lightblue")
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45,ha='right');

# %% [markdown]
# ### Genre vs. Profit

# %%
genre_profit_order = exploded_imdb_tn.groupby('genres').median()['profit'].sort_values(ascending=False).index

# %%
with plt.style.context('seaborn-notebook'):
    fig, ax = plt.subplots(figsize=(15,5))
    sns.barplot(x=exploded_imdb_tn['genres'], y=exploded_imdb_tn['profit'], estimator=np.median, ci=None, order=genre_profit_order, palette='viridis')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45,ha='right');

# %% [markdown]
# ### Genre vs. ROI

# %%
exploded_imdb_tn['ROI %'] = (exploded_imdb_tn['worldwide_gross']/exploded_imdb_tn['production_budget'])*100

# %%
genre_roi_order = exploded_imdb_tn.groupby('genres').median()['ROI %'].sort_values(ascending=False).index

# %%
with plt.style.context('seaborn-notebook'):
    fig, ax = plt.subplots(figsize=(15,5))
    sns.barplot(x=exploded_imdb_tn['genres'], y=exploded_imdb_tn['ROI %'], estimator=np.median, ci=None, 
                order=genre_roi_order, palette='dark:seagreen_r')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45,ha='right');

# %% [markdown]
# ### Genre vs. Profit %

# %%
genre_profit_order = exploded_imdb_tn.groupby('genres').median()['profit %'].sort_values(ascending=False).index

# %%
with plt.style.context('seaborn-notebook'):
    fig, ax = plt.subplots(figsize=(15,5))
    sns.barplot(x=exploded_imdb_tn['genres'], y=exploded_imdb_tn['profit %'], estimator=np.median, ci=None, order=genre_profit_order)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45,ha='right');

# %%
exploded_imdb_tn[exploded_imdb_tn['genres']=='Horror']
# Out:
#      id  release_date                movie  production_budget  domestic_gross  \
# 40   69  Jun 21, 2013          World War Z          190000000       202359711
# 62    2  Nov 22, 2017                 Coco          175000000       209726015
# 311  66  Mar 24, 2017                 Life           58000000        30234022
# 438  24   Sep 8, 2017                   It           35000000       327481748
# 491  70   Feb 1, 2013          Warm Bodies           30000000        66380662
# 604  88  Mar 22, 2019                   Us           20000000       175006930
# 606  93  Jul 19, 2013        The Conjuring           20000000       137400141
# 644  38   Oct 1, 2010            Let Me In           20000000        12134935
# 669  66   Apr 6, 2018        A Quiet Place           17000000       188024361
# 734  14  Mar 15, 2013             The Call           12800000        51872378
# 770  36  Oct 19, 2018            Halloween           10000000       159342015
# 775  56   Jun 8, 2018           Hereditary           10000000        44069456
# 858  49  Feb 24, 2017              Get Out            5000000       176040665
# 860  54  Mar 11, 2016  10 Cloverfield Lane            5000000        72082999
# 908  69  Oct 12, 2012             Sinister            3000000        48086903
# 935  41  Nov 28, 2014         The Babadook            2000000          950792
#
#      worldwide_gross     profit  profit % release_month  release_mo_num  ...  \
# 40         531514650  341514650     180.0           Jun               6  ...
# 62         798008101  623008101     356.0           Nov              11  ...
# 311        100929666   42929666      74.0           Mar               3  ...
# 438        697457969  662457969    1893.0           Sep               9  ...
# 491        115121608   85121608     284.0           Feb               2  ...
# 604        254210310  234210310    1171.0           Mar               3  ...
# 606        318000141  298000141    1490.0           Jul               7  ...
# 644         28270399    8270399      41.0           Oct              10  ...
# 669        334522294  317522294    1868.0           Apr               4  ...
# 734         69821476   57021476     445.0           Mar               3  ...
# 770        254900667  244900667    2449.0           Oct              10  ...
# 775         70133905   60133905     601.0           Jun               6  ...
# 858        255367951  250367951    5007.0           Feb               2  ...
# 860        108286422  103286422    2066.0           Mar               3  ...
# 908         87727807   84727807    2824.0           Oct              10  ...
# 935          7482387    5482387     274.0           Nov              11  ...
#
#           original_title start_year runtime_minutes  genres  averagerating  \
# 40           World War Z       2013           116.0  Horror            7.0
# 62                  Coco       2017            98.0  Horror            7.4
# 311                 Life       2017           104.0  Horror            6.6
# 438                   It       2017           135.0  Horror            7.4
# 491          Warm Bodies       2013            98.0  Horror            6.9
# 604                   Us       2019           116.0  Horror            7.1
# 606        The Conjuring       2013           112.0  Horror            7.5
# 644            Let Me In       2010           116.0  Horror            7.1
# 669        A Quiet Place       2018            90.0  Horror            7.6
# 734             The Call       2013            94.0  Horror            6.7
# 770            Halloween       2018           106.0  Horror            6.6
# 775           Hereditary       2018           127.0  Horror            7.3
# 858              Get Out       2017           104.0  Horror            7.7
# 860  10 Cloverfield Lane       2016           103.0  Horror            7.2
# 908             Sinister       2012           110.0  Horror            6.8
# 935         The Babadook       2014            94.0  Horror            6.8
#
#      numvotes  genre1     genre2    genre3        ROI %
# 40     553751  Action  Adventure    Horror   279.744553
# 62         35  Horror        NaN       NaN   456.004629
# 311    182840  Horror     Sci-Fi  Thriller   174.016666
# 438    359123  Horror   Thriller       NaN  1992.737054
# 491    208709  Comedy     Horror   Romance   383.738693
# 604    102511  Horror    Mystery  Thriller  1271.051550
# 606    397233  Horror    Mystery  Thriller  1590.000705
# 644    107012   Drama    Fantasy    Horror   141.351995
# 669    305031   Drama     Horror    Sci-Fi  1967.778200
# 734    103780   Crime      Drama    Horror   545.480281
# 770     88395  Horror   Thriller       NaN  2549.006670
# 775    151571   Drama     Horror   Mystery   701.339050
# 858    400474  Horror    Mystery  Thriller  5107.359020
# 860    260383   Drama     Horror   Mystery  2165.728440
# 908    198345  Horror    Mystery  Thriller  2924.260233
# 935    171411   Drama     Horror       NaN   374.119350
#
# [16 rows x 23 columns]

# %%
import os
folder ='./office_hours'
os.makedirs(folder, exist_ok=True)

# %%
imdb_tn_filtered.to_csv(f"{folder}/berke_dataset2.csv", index=False)

# %%
exploded_imdb_tn.loc[exploded_imdb_tn['genres']=='Musical',:]
# Out:
#      id  release_date                    movie  production_budget  \
# 221  25  Dec 20, 2017     The Greatest Showman           84000000
# 817  54  May 31, 2013  Yeh Jawaani Hai Deewani            8300000
#
#      domestic_gross  worldwide_gross     profit  profit % release_month  \
# 221       174340174        386665550  302665550     360.0           Dec
# 817         3827466         50827466   42527466     512.0           May
#
#      release_mo_num  ...           original_title start_year runtime_minutes  \
# 221              12  ...     The Greatest Showman       2017           105.0
# 817               5  ...  Yeh Jawaani Hai Deewani       2013           160.0
#
#       genres  averagerating  numvotes     genre1  genre2   genre3       ROI %
# 221  Musical            7.6    199663  Biography   Drama  Musical  460.316131
# 817  Musical            7.1     33971     Comedy   Drama  Musical  612.379108
#
# [2 rows x 23 columns]

# %%
imdb_tn_filtered.loc[imdb_tn_filtered['movie']=='Beauty and the Beast',:]
# Out:
#     id  release_date                 movie  production_budget  domestic_gross  \
# 81  35  Mar 17, 2017  Beauty and the Beast          160000000       504014165
#
#     worldwide_gross      profit  profit % release_month  release_mo_num  ...  \
# 81       1259199706  1099199706     687.0           Mar               3  ...
#
#            primary_title        original_title start_year runtime_minutes  \
# 81  Beauty and the Beast  Beauty and the Beast       2017           129.0
#
#                         genres  averagerating numvotes  genre1   genre2  \
# 81  [Family, Fantasy, Musical]            7.2   238325  Family  Fantasy
#
#      genre3
# 81  Musical
#
# [1 rows x 22 columns]

# %% [markdown]
# # Movie Budget vs. Rating & Movie Budget vs. Financials

# %%
a = imdb_tn_filtered
a['ROI %'] = (a['worldwide_gross']/a['production_budget'])*100
# Out:
# <ipython-input-513-5ea35b07874a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['ROI %'] = (a['worldwide_gross']/a['production_budget'])*100

# %%
a = tn_movie_budgets[tn_movie_budgets['release_year']>2008]
b = pd.merge(a, imdb, left_on=['movie', 'release_year'], right_on=['original_title', 'start_year'])
    
#     fig, ax = plt.subplots(ncols=2, figsize=(15,5))
    
#     sns.regplot(x=b['production_budget'], y=b['averagerating'], color='lightcoral', ax=ax[0])
#     sns.regplot(x=imdb_tn_filtered['production_budget'], y=imdb_tn_filtered['averagerating'], color='lightcoral', ax=ax[1])
#     #industry
#     ax[0].set_ylim(0.0,10.0)
#     ax[0].set_xlabel('Production Budget')
#     ax[0].set_ylabel('Average Rating')
#     ax[0].set_title('Average Rating vs. Production Budget for Movies Released Between 2009-2019')
#     #succesful movies
#     ax[1].set_ylim(6.5,10)
#     ax[1].set_xlabel('Production Budget')
#     ax[1].set_ylabel('Average Rating')
#     ax[1].set_title('Average Rating vs. Production Budget for Succesful Movies Between 2009-2019')

# %%
unsuccessful_df = b[(b['averagerating']<6.5) & (b['profit %']<25)]
with plt.style.context('seaborn-notebook'):
    fig, ax = plt.subplots(figsize=(10,5))
    sns.regplot(data=imdb_tn_filtered, x='production_budget', y='averagerating', color='seagreen', ax=ax, label='Successful Movies')
    sns.regplot(data=unsuccessful_df, x='production_budget', y='averagerating', color='tomato', ax=ax, label='Unsuccessful Movies')
    ax.legend()
    ax.set_xlabel('Production Budget')
    ax.set_ylabel('Average Movie Rating')
    ax.set_ylim(0,10)

# %%
with plt.style.context('seaborn-notebook'):
    fig, ax = plt.subplots(figsize=(10,5))
    sns.regplot(x=imdb_tn_filtered['production_budget'], y=imdb_tn_filtered['worldwide_gross'], color='seagreen', ax=ax, label='Successful Movies')
    sns.regplot(x=unsuccessful_df['production_budget'], y=unsuccessful_df['worldwide_gross'], color='tomato', ax=ax, label='Unsuccessful Movies')
    ax.legend()
    ax.set_xlabel('Production Budget')
    ax.set_ylabel('Total Revenue')

# %%
# with plt.style.context('seaborn-notebook'):
#     fig, ax = plt.subplots(ncols=2, figsize=(15,5))
#     sns.regplot(x=b['production_budget'], y=b['worldwide_gross'], color='#5A9', ax=ax[0])
#     sns.regplot(x=imdb_tn_filtered['production_budget'], y=imdb_tn_filtered['worldwide_gross'], color='#5A9', ax=ax[1])
#     #industry
#     ax[0].set_xlabel('Production Budget')
#     ax[0].set_ylabel('Total Revenue')
#     ax[0].set_title('Production Budget vs. Total Revenue for Movies Released Between 2009-2019')
#     #succesful movies
#     ax[1].set_xlabel('Production Budget')
#     ax[1].set_ylabel('Total Revenue')
#     ax[1].set_title('Production Budget vs. Total Revenue for Succesful Movies Between 2009-2019')
# # sns.regplot(x=imdb_tn_filtered['production_budget'], y=imdb_tn_filtered['worldwide_gross'], color='#5A9')

# %%
with plt.style.context('seaborn-notebook'):
    fig, ax = plt.subplots(figsize=(10,5))
    sns.regplot(x=imdb_tn_filtered['production_budget'], y=imdb_tn_filtered['profit'], color='seagreen', ax=ax, label='Successful Movies')
    sns.regplot(x=unsuccessful_df['production_budget'], y=unsuccessful_df['profit'], color='tomato', ax=ax, label='Unsuccessful Movies')
    ax.legend()
    ax.set_xlabel('Production Budget')
    ax.set_ylabel('Profit')

# %%
# with plt.style.context('seaborn-notebook'):
#     fig, ax = plt.subplots(ncols=2, figsize=(15,5))
#     sns.regplot(x=b['production_budget'], y=b['profit'], color='purple', ax=ax[0])
#     sns.regplot(x=imdb_tn_filtered['production_budget'], y=imdb_tn_filtered['profit'], color='purple', ax=ax[1])
#     #industry
#     ax[0].set_xlabel('Production Budget')
#     ax[0].set_ylabel('Total Profit')
#     ax[0].set_title('Production Budget vs. Total Profit for Movies Released Between 2009-2019')
#     #succesful movies
#     ax[1].set_xlabel('Production Budget')
#     ax[1].set_ylabel('Total Profit')
#     ax[1].set_title('Production Budget vs. Total Profit  for Succesful Movies Between 2009-2019')
# # fig, ax = plt.subplots()
# # sns.regplot(x=imdb_tn_filtered['production_budget'], y=imdb_tn_filtered['profit'], color='purple');

# %%
with plt.style.context('seaborn-notebook'):
    fig, ax = plt.subplots(figsize=(10,5))
    sns.regplot(x=imdb_tn_filtered['production_budget'], y=imdb_tn_filtered['profit %'], color='seagreen', ax=ax, label='Successful Movies')
    sns.regplot(x=unsuccessful_df['production_budget'], y=unsuccessful_df['profit %'], color='tomato', ax=ax, label='Unsuccessful Movies')
    ax.legend()
    ax.set_xlabel('Production Budget')
    ax.set_ylabel('Profit %')

# %%
# fig, ax = plt.subplots()
# sns.regplot(x=imdb_tn_filtered['production_budget'], y=imdb_tn_filtered['profit %']);
